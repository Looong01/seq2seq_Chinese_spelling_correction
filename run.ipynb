# %%
# %run preprocess.py
# Out:
# save line size:1943 to /home/ypd-19-5/LZL/PyTorch/Web_Search_Tech/seq2seq/output/train.txt
# save line size:216 to /home/ypd-19-5/LZL/PyTorch/Web_Search_Tech/seq2seq/output/valid.txt

# %%
# %run train.py
# Out:
# device: cuda
# src: <sos> 新 爱 父 亲 。 <eos>
# trg: <sos> 亲 爱 父 亲 。 <eos>
# Seq2Seq(
#   (encoder): Encoder(
#     (embed): Embedding(1828, 128)
#     (rnn): GRU(128, 128, batch_first=True, bidirectional=True)
#     (dropout): Dropout(p=0.25, inplace=False)
#     (fc): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (decoder): Decoder(
#     (embed): Embedding(1690, 128)
#     (attention): Attention(
#       (linear_in): Linear(in_features=256, out_features=128, bias=False)
#       (linear_out): Linear(in_features=384, out_features=128, bias=True)
#     )
#     (rnn): GRU(128, 128, batch_first=True)
#     (out): Linear(in_features=128, out_features=1690, bias=True)
#     (dropout): Dropout(p=0.25, inplace=False)
#   )
# )
# Epoch :0/200000, iteration :0/1 loss:7.4349
# Epoch :0/200000, Training loss:7.4349
# Epoch:0, save new bert model:/home/ypd-19-5/LZL/PyTorch/Web_Search_Tech/seq2seq/output/model_sighan_seq2seq.pth
# Evaluation loss 7.415285110473633
# ...

# %%
# %run infer.py
# Out:
# device: cuda
# input  : 就是若没有搜到证据的话，以后就不许在谈论这件事，也应该还我一个清白。
# predict: 就是若没有搜到证据的话，以后就不许在谈论这件事，也应该还我一个清白。
# target:  就是若没有搜到证据的话，以后就不许再谈论这件事，也应该还我一个清白。
#
# input  : 如果要学的东西不好玩，她们常常学的非常不好，他门不懂为什么现在哪里都不能去，为什么要做无聊的事。
# predict: 如果要学的东西不好玩，她们常常学的非常不好，他们不懂为什么现在那里都不能去，为什么要做无聊的事。
# target:  如果要学的东西不好玩，她们常常学的非常不好，他们不懂为什么现在哪里都不能去，为什么要做无聊的事。
#
# input  : 夏天也不错，不太热可以塞太阳。
# predict: 夏天也不错，不太热可以塞太阳。
# target:  夏天也不错，不太热可以晒太阳。
#
# input  : 去年，美国华人友请我们来桃园看叔叔家。
# predict: 去年，美国华人有请我们来联我们来监园。
# target:  去年，美国华人有请我们来桃园看叔叔家。
#
# input  : 我特别喜欢黑麦面包，今天上午作的黑麦面包非常好。
# predict: 我特别喜欢黑，今天上午做的黑期面包非常好。
# target:  我特别喜欢黑麦面包，今天上午做的黑麦面包非常好。
#
# input  : 但还是希望你首先平息你的反应，其次尽量跟那位同学购通你们俩之间的问题及对这件事情的看法，好让不要再发生这样伤害彼此的事情。
# predict: 但还是希望你首先平息你的反应，其次尽量跟那位同学选通你们配之间的看法，好让不要再发生这样伤害。
# target:  但还是希望你首先平息你的反应，其次尽量跟那位同学沟通你们俩之间的问题及对这件事情的看法，好让不要再发生这样伤害彼此的事情。
#
# input  : 「青少年上网时数多」这个事情发生了因为我们世界已请变成了一个地就村，所以每个人都要知道全世界有甚么新闻。
# predict: 「青少年上网时数多」这个事情发生了因为我们世界已经变成了一个地就村，所以每个人都要知道全世界有甚么新闻。
# ...
